# %% [markdown]
# #**Pandas**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array([['John',25,'Delhi','A',10,200],['Riya',27,'Mumbai','B',15,300],
 ['Aman',24,'Pune','A',np.nan,200],['Neha',26,'Kolkata','C',10,200],
  ['Arjun',25,'Jaipur','B',15,np.nan],['Musa',28,'Istanbul','A',10,150],
   ['Peter',24,'Berlin','A',15,200],['Alex',25,'Potsdam','B',10,250]],object)

# %% [markdown]
# ### **Task 0.** A numpy two dimentional array is initialized in an object $data$. Store it in a pandas dataframe $df$ by assigning column labels as follows: $name,age,city,category,unit\_sold,unit\_price$.

# %%
# Write your code here

# %% [markdown]
# ###**Task 1.** After loading data, it is important to understand its structure and content. Call the suitable method that allows you to inspect rows, summary statistics and metadata.

# %%
# Write your code here

# %% [markdown]
# ###**Task 2.** Datasets often contain empty or missing values. Pandas provides functions to detect, remove or replace these values. Check for those empty or missing values and remove or replace them.

# %%
# Write your code here

# %% [markdown]
# ###**Task 3.** Select and filter the dataset where the $age$ value is greater than $25$.

# %%
# Write your code here

# %% [markdown]
# ###**Task 4.** Create a new column $revenue$ based on existing columns $unit\_sold$ and $unit\_price$ from the DataFrame.

# %%
# Write your code here

# %% [markdown]
# ###**Task 5.** Organize data into $categories$ and compute $sum$ for each group.

# %%
# Write your code here

# %% [markdown]
# ###**Task 6.** How evenly is $revenue$ distributed across $categories$?

# %%
# Write your code here

# %% [markdown]
# ### **Task 7.** Which $category$ generates the highest $revenue$?
#
# ***Note:*** Show the results in a bar plot.

# %%
# Write your code here
