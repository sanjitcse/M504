# %% [markdown]
# # Python Basics

# %% [markdown]
# ##1. Print Hello
# Write a program to print 'Hello, World!'

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ##2. Addition
# Take two numbers and print their sum.

# %%
# Example:
a = 5
b = 3
# Your code here

# %% [markdown]
# ##3. Subtraction
# Take two numbers, subtract them and print the result.

# %%
# Example:
a = 9
b = 2
# Your code here

# %% [markdown]
# ##4. Swap
# Swap two numbers without using a third variable.

# %%
# Example:
a = 8
b = 5
# Your code here

# %% [markdown]
# ##5. Division
# Read two numbers from keyboard, divide them and print the result.

# %%
# Example:
a = int (input())
b = int (input())
# Your code here

# %% [markdown]
# ##6. Conversion
#
# Read temparature in Celsius and convert it into Fahrenheit.
#
# For example:
#
# Fahrenheit = (Celsius * 1.8)+32

# %%
#Example:

c = float (input())

# Write your code here

# %% [markdown]
# ##7. Square root
#
# Read a number from keyboard, calculate the square root and display it.

# %%
# Write your code here

# %% [markdown]
# ##Python Expressions
#
# An expression is a piece of code that produces a value. Examples:
#
# - `2 + 3`
# - `10 / 2`
# - `len('Python')`

# %% [markdown]
# ##8. Evaluate these expressions and observe the results.
#
# - `2 + 5`
# - `10 - 3`
# - `4 * 6`
# - `12 / 4`

# %%
# Write your code here

# %% [markdown]
# ##9. Store the result of an expression in a variable.
#
# - `(8 + 2) * 3`

# %%
# Write your code here

# %% [markdown]
# ##10. Count Seconds in a Decade
# Write a Python program to calculate the number of seconds in 10 years. Assume that we have 2 leap years in this period. Assign the result into a variable named `seconds_in_10_years`.

# %%
# Write your code here

# %% [markdown]
# ##11. Compute the Area of a Circle
# Write a Python program that computes the area of a circle based on a given radius. The area of circle can be computed by the following formula: $ a = \pi r^2 $.

# %%
# Write your code here

# %% [markdown]
# ##12. Compute Maximum of Numbers
# Write a Python program that computes the maximum of two inputs:
# - The first input should be the absolute of -4.
# - The second input should be the length of the string `"abc"`.

# %%
# Write your code here

# %% [markdown]
# ##13. Compute Euclidean Distance
# Write a Python program to compute the Euclidean distance between two given points $ (x_1, y_1) $ and $ (x_2, y_2) $, which is $ \sqrt{(x_1 - x_2)^2 + (y_1 - y_2)^2} $.

# %%
# Write your code here

# %% [markdown]
# ##14. Convert Fahrenheit to Celsius
# Write a Python program to convert fahrenheit to celsius based on the the following formula: $ C = (F - 32) \times \frac{5}{9}. $

# %%
# Write your code here
